# %%
import numpy as np 
import pandas as pd
from datetime import date

# %%
#enter name and age and it should show when he turns hundred


Name = input("Enter the Name:")
Age = int(input("Enter the Age:"))
year=date.today().year
print(Name,"will turn 100 on year :",year-Age+100)
# Out:
# Enter the Name:
# Enter the Age:30
#  will turn 100 on year : 2092

# %%
# What is pandas group by 

file = pd.read_excel(r"C:\Users\_kv2\Documents\Downloads\Auto_temp.xlsx")
file.head(10)
file.columns
# Out:
# Index(['Unnamed: 0', 'symboling', 'normalized_losses', 'make', 'fuel_type',
#        'aspiration', 'num_doors', 'body_style', 'drive_wheels',
#        'engine_location', 'wheel_base', 'length', 'width', 'height',
#        'curb_weight', 'engine_type', 'num_cylinders', 'engine_size',
#        'fuel_system', 'bore', 'stroke', 'compression_ratio', 'horsepower',
#        'peak_rpm', 'city_mpg', 'highway_mpg', 'price'],
#       dtype='object')

# %%
df_group=file.groupby([file['fuel_type'],file['make']]).mean()
df_group
# Out:
#                          Unnamed: 0  symboling  normalized_losses  wheel_base  \
# fuel_type make
# diesel    mazda           64.500000   0.000000                NaN  101.850000
#           mercedes-benz   68.500000  -0.750000          93.000000  110.575000
#           nissan          90.000000   1.000000         128.000000   94.500000
#           peugot         112.000000   0.000000         161.000000  110.420000
#           toyota         163.666667  -0.333333          82.333333   97.933333
#           volkswagen     186.250000   1.500000         103.333333   98.075000
#           volvo          203.000000  -1.000000          95.000000  109.100000
# gas       alfa-romero      1.000000   2.333333                NaN   90.566667
#           audi             6.000000   1.285714         161.000000  102.271429
#           bmw             13.500000   0.375000         190.000000  103.162500
#           chevrolet       19.000000   1.000000         100.000000   92.466667
# ...

# %% [markdown]
# #pd.pivot_table(file,columns= ['length','width','height'],index=['fuel_type','make'],aggfunc=np.sum)
# #table = pd.pivot_table(df, values=['col1', 'col2'], index=['cat1', 'cat2'],
#                     aggfunc={'col1': np.mean,
#                              'col2': np.mean})

# %%
#How to create a dataframe from list?N
 

lis1 = ["vani","sreenath","varun"]
lis2 = [20,21,22]
df1 = pd.DataFrame((zip(lis1,lis2)),index=['a','b','c'],columns= ["Name","Age"])
df1
# Out:
#        Name  Age
# a      vani   20
# b  sreenath   21
# c     varun   22

# %%
list1 = [["vani" ,200],['sreenath',500]]
df2 = pd.DataFrame(list1,index=['a','b'],columns= ["Name","Salary"])
df2
# Out:
#        Name  Salary
# a      vani     200
# b  sreenath     500

# %%
#What are the ways to combine the dataframe in pandas. Give an example for each
#  Join , concatenate ,append

#The concat() function in pandas is used to append either columns or rows from one DataFrame to another
list = [df1,df2]
pd.concat(list)
# Out:
#        Name  Age
# a      vani   20
# b  sreenath   21
# c     varun   22
# a      vani  200
# b  sreenath  500

# %%
# Combining DataFrames using a common field is called joining.By default the join is always outer join 


list = [df1,df2]
pd.concat(list,join="inner")
# Out:
#        Name  Age
# a      vani   20
# b  sreenath   21
# c     varun   22
# a      vani  200
# b  sreenath  500

# %%
df1.append(df2)
# Out:
#        Name  Age
# a      vani   20
# b  sreenath   21
# c     varun   22
# a      vani  200
# b  sreenath  500

# %% [markdown]
# #5.	What is the difference between list and tuples in Python?
#
# #List
#
# 1.list is represented in squarebrackets
# 2.list is mutable
# 3.Takes is more memory than tuple
# 4.Both are ordered collection of items
#
# Tuple
# 1. Tuples are represented using () simple brackets
# 2. they are immutable
# 3. they take less memory than list
# 4. they are also ordered collection of items
# 5. its faster than list

# %%
#6.	Find out the mean, median and standard deviation of this numpy array -> 
c=np.array([1,5,3,100,4,48])
print("Mean of elements in Array 'C' is :",round(np.mean(c),1))
print("Median of elements in Array 'C' is :",np.median(c))
print("Standard deviation of elements in Array 'C' is :",round(np.std(c),1))
# Out:
# Mean of elements in Array 'C' is : 26.8
# Median of elements in Array 'C' is : 4.5
# Standard deviation of elements in Array 'C' is : 36.6

# %%
7.	How will you remove duplicate elements from a list?
lis =[1,2,1,32,2,1,89,8,0,9,9,10]
print("unique values",set(lis))
# Out:
# unique values {32, 1, 2, 0, 8, 9, 10, 89}

# %%
np.unique(lis)
# Out:
# array([ 0,  1,  2,  8,  9, 10, 32, 89])

# %% [markdown]
# #8.	What is a map() function in Python? Give an example
# The map() function applies a given function to each item of an iterable (list, tuple etc.) and returns a list of the results

# %%
# return square of all values 
def sqr(n):
    return n*n

number_list = [1,2,3,4,5]
result=list(map(sqr,number_list))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-78-8833d1bfd68e> in <module>
#       4
#       5 number_list = [1,2,3,4,5]
# ----> 6 result=list(map(sqr,number_list))
#
# TypeError: 'list' object is not callable

# %%
number_list = [1,2,3,4,5]
result=[(map(lambda x:x*x ,number_list))]

# %%
left = pd.DataFrame(
    {
        "key1": ["K0", "K0", "K1", "K2"],
        "key2": ["K0", "K1", "K0", "K1"],
        "A": ["A0", "A1", "A2", "A3"],
        "B": ["B0", "B1", "B2", "B3"],
    }
)


right = pd.DataFrame(
    {
        "key1": ["K0", "K1", "K1", "K2"],
        "key2": ["K0", "K0", "K0", "K0"],
        "C": ["C0", "C1", "C2", "C3"],
        "D": ["D0", "D1", "D2", "D3"],
    }
)
print(left, "\n", right)
# Out:
#   key1 key2   A   B
# 0   K0   K0  A0  B0
# 1   K0   K1  A1  B1
# 2   K1   K0  A2  B2
# 3   K2   K1  A3  B3
#    key1 key2   C   D
# 0   K0   K0  C0  D0
# 1   K1   K0  C1  D1
# 2   K1   K0  C2  D2
# 3   K2   K0  C3  D3

# %%
#merge()
pd.merge(left,right,on='key2',how = 'left')
# Out:
#   key1_x key2   A   B key1_y    C    D
# 0     K0   K0  A0  B0     K0   C0   D0
# 1     K0   K0  A0  B0     K1   C1   D1
# 2     K0   K0  A0  B0     K1   C2   D2
# 3     K0   K0  A0  B0     K2   C3   D3
# 4     K0   K1  A1  B1    NaN  NaN  NaN
# 5     K1   K0  A2  B2     K0   C0   D0
# 6     K1   K0  A2  B2     K1   C1   D1
# 7     K1   K0  A2  B2     K1   C2   D2
# 8     K1   K0  A2  B2     K2   C3   D3
# 9     K2   K1  A3  B3    NaN  NaN  NaN

# %%
pd.merge(left,right,on=['key2','key1'])
# Out:
#   key1 key2   A   B   C   D
# 0   K0   K0  A0  B0  C0  D0
# 1   K1   K0  A2  B2  C1  D1
# 2   K1   K0  A2  B2  C2  D2

# %%
#9.	What is pass in Python?

# %%
#10.	What is vstack() in numpy? Give an example
c=np.array([1,2,3,4,5,6])
np.vstack(c)
# Out:
# array([[1],
#        [2],
#        [3],
#        [4],
#        [5],
#        [6]])
